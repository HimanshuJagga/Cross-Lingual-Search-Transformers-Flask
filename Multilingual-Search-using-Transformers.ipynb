# %% [markdown]
# # 🌐 Cross-Lingual Information Retrieval using Transformers
#
# Welcome to the project!
#
# In this notebook, we’ll build a real-world **Cross-Lingual Information Retrieval** system using **Hugging Face Transformers** and **Sentence Transformers**.
#
# ### 🔍 Goal:
# Given a **query in one language** (e.g., English), retrieve the most **relevant document in another language** (e.g., French, Spanish, Hindi).
#
# ### ✅ What You'll Learn:
# - How to use multilingual transformer models like **MiniLM** from Hugging Face to generate sentence embeddings for cross-lingual search
# - Generate **semantic embeddings** from text
# - Use **cosine similarity** for semantic search
# - Build a multilingual search system (end-to-end)
#
# Let’s get started!

# %% [markdown]
# ## 🔧 Step 1: Project Setup
#
# In this step, we'll:
# - Install all required libraries
# - Import key modules
#
# We'll use:
#
# - `sentence-transformers`: for generating sentence embeddings
# - `transformers`: (under the hood) for multilingual models
# - **Cosine Similarity** (from `sentence-transformers.util`) for comparing embeddings

# %%
# Install the necessary libraries
# !pip install -q sentence-transformers transformers datasets tf-keras

# %%
# Basic Python libraries
import numpy as np
import pandas as pd
import torch
import warnings
warnings.filterwarnings('ignore')

# Sentence Transformers (built on Hugging Face)
from sentence_transformers import SentenceTransformer, util

# %% [markdown]
# ## 📂 Step 2: Load Tatoeba Dataset via Hugging Face
#
# We'll utilize the Tatoeba dataset from Hugging Face, which contains multilingual sentence pairs. This dataset is ideal for building a cross-lingual information retrieval system.
#
# We'll focus on English-French sentence pairs for this project.

# %%
from datasets import load_dataset

# Load the Tatoeba dataset with trusted custom code
dataset = load_dataset("tatoeba", lang1="en", lang2="fr", split="train", trust_remote_code=True)

# Display first 5 sentence pairs
for i in range(5):
    print(f"English: {dataset[i]['translation']['en']}")
    print(f"French:  {dataset[i]['translation']['fr']}\n")
# Out:
# English: When he asked who had broken the window, all the boys put on an air of innocence.
# French:  Lorsqu'il a demandé qui avait cassé la fenêtre, tous les garçons ont pris un air innocent.
#
# English: Then, when he asked who had broken the window, all the boys acted innocent.
# French:  Lorsqu'il a demandé qui avait cassé la fenêtre, tous les garçons ont pris un air innocent.
#
# English: Let's try something.
# French:  Essayons quelque chose !
#
# English: Let's try something.
# French:  Tentons quelque chose !
#
# English: Let's try something.
# French:  Essayons quelque chose.

# %% [markdown]
# ## 🔢 Step 3: Generate Embeddings with a Multilingual Transformer
#
# We'll now convert both English and French sentences into dense vector embeddings using the model:
#
# 📌 `paraphrase-multilingual-MiniLM-L12-v2`
# This model supports over 50 languages and maps similar sentences (even across languages!) to similar embeddings.
#
# We'll use `SentenceTransformer.encode()` to:
# - Encode all English queries
# - Encode all French documents
# - Store them in a format ready for similarity comparison

# %%
from sentence_transformers import SentenceTransformer

# Load multilingual model
model = SentenceTransformer('paraphrase-multilingual-MiniLM-L12-v2')

# Confirm it's loaded
print("Model loaded successfully!")
# Out:
# Model loaded successfully!

# %%
# Convert sliced dataset to a list of dictionaries
samples = dataset.select(range(200))

# Extract English and French sentences
english_sentences = [sample['translation']['en'] for sample in samples]
french_sentences = [sample['translation']['fr'] for sample in samples]

# Preview
for en, fr in zip(english_sentences, french_sentences):
    print(f"EN: {en}")
    print(f"FR: {fr}\n")
# Out:
# EN: When he asked who had broken the window, all the boys put on an air of innocence.
# FR: Lorsqu'il a demandé qui avait cassé la fenêtre, tous les garçons ont pris un air innocent.
#
# EN: Then, when he asked who had broken the window, all the boys acted innocent.
# FR: Lorsqu'il a demandé qui avait cassé la fenêtre, tous les garçons ont pris un air innocent.
#
# EN: Let's try something.
# FR: Essayons quelque chose !
#
# EN: Let's try something.
# FR: Tentons quelque chose !
#
# EN: Let's try something.
# FR: Essayons quelque chose.
#
# EN: I have to go to sleep.
# FR: Je dois aller dormir.
#
# EN: I have to go to sleep.
# FR: Il faut que j'aille dormir.
#
# EN: I can't abide that fellow.
# FR: Je ne supporte pas ce type.
#
# EN: I can't bear that fellow.
# FR: Je ne supporte pas ce type.
#
# EN: I can't stand that guy.
# FR: Je ne supporte pas ce type.
#
# EN: Today is June 18th and it is Muiriel's birthday!
# FR: Aujourd'hui nous sommes le 18 juin et c'est l'anniversaire de Muiriel !
#
# EN: Today is June 18th and it is Muiriel's birthday!
# FR: Aujourd'hui c'est le 18 juin, et c'est l'anniversaire de Muiriel.
#
# EN: Today is June 18th and it is Muiriel's birthday!
# FR: Aujourd'hui on est le 18 juin et c'est l'anniversaire de Muiriel !
#
# EN: Muiriel is 20 now.
# FR: Muiriel a 20 ans maintenant.
#
# EN: The password is "Muiriel".
# FR: Le mot de passe est « Muiriel ».
#
# EN: I will be back soon.
# FR: Je serai bientôt de retour.
#
# EN: I will be back soon.
# FR: Je serai de retour dans une minute.
#
# EN: I will be back soon.
# FR: Je reviens tout de suite.
#
# EN: I will be back soon.
# FR: Je reviens vite.
#
# EN: I will be back soon.
# FR: Je reviens de suite.
#
# EN: I'm at a loss for words.
# FR: J'en perds mes mots.
#
# EN: I'm at a loss for words.
# FR: Les mots me manquent.
#
# EN: I'm at a loss for words.
# FR: Les mots me font défaut.
#
# EN: I'm at a loss for words.
# FR: Je ne trouve pas les mots.
#
# EN: This is never going to end.
# FR: Ça ne va jamais finir.
#
# EN: This is never going to end.
# FR: Ça n'en finira jamais.
#
# EN: This is never going to end.
# FR: Ça n'en finit plus.
#
# EN: I just don't know what to say.
# FR: Je ne sais simplement pas quoi dire...
#
# EN: I just don't know what to say.
# FR: Je ne sais quoi dire.
#
# EN: I just don't know what to say.
# FR: Je ne sais pas quoi dire.
#
# EN: I just don't know what to say.
# FR: Je ne sais pas quoi dire, tout simplement.
#
# EN: That was an evil bunny.
# FR: C’était un méchant lapin.
#
# EN: That was an evil bunny.
# FR: C’était un lapin maléfique.
#
# EN: That was an evil bunny.
# FR: C’était un lapin diabolique.
#
# EN: I was in the mountains.
# FR: J'étais dans les montagnes.
#
# EN: I was in the mountains.
# FR: Je me trouvais dans les montagnes.
#
# EN: Is it a recent picture?
# FR: Est-ce que c'est une photo récente ?
#
# EN: Is it a recent picture?
# FR: Est-ce une photo récente ?
#
# EN: I don't know if I have the time.
# FR: Je ne sais pas si j'ai le temps.
#
# EN: Education in this world disappoints me.
# FR: L'éducation dans ce monde me déçoit.
#
# EN: You're in better shape than I am.
# FR: Tu es en meilleure forme que moi.
#
# EN: You're in better shape than I am.
# FR: Vous êtes en meilleure forme que moi.
#
# EN: You are in my way.
# FR: Tu es sur mon chemin.
#
# EN: You are in my way.
# FR: Vous êtes sur mon chemin.
#
# EN: This will cost €30.
# FR: Ça coûtera 30 €.
#
# EN: This will cost €30.
# FR: Ça va faire 30 euros.
#
# EN: I make €100 a day.
# FR: Je gagne 100€ par jour.
#
# EN: I make €100 a day.
# FR: Je gagne cent euros par jour.
#
# EN: I may give up soon and just nap instead.
# FR: Il se peut que j'abandonne bientôt et fasse une sieste à la place.
#
# EN: It's because you don't want to be alone.
# FR: C'est parce que tu ne veux pas être seul.
#
# EN: It's because you don't want to be alone.
# FR: C'est parce que vous ne voulez pas être seul.
#
# EN: It's because you don't want to be alone.
# FR: C'est parce que vous ne voulez pas être seule.
#
# EN: It's because you don't want to be alone.
# FR: C'est parce que tu ne veux pas être seule.
#
# EN: It's because you don't want to be alone.
# FR: C'est parce que vous ne voulez pas être seuls.
#
# EN: It's because you don't want to be alone.
# FR: C'est parce que vous ne voulez pas être seules.
#
# EN: That won't happen.
# FR: Ça n'arrivera pas.
#
# EN: Sometimes he can be a strange guy.
# FR: Parfois il peut être un gars bizarre.
#
# EN: Sometimes he can be a strange guy.
# FR: Ce mec est bizarre par moment.
#
# EN: I'll do my best not to disturb your studying.
# FR: Je ferai de mon mieux pour ne pas perturber tes révisions.
#
# EN: I can only wonder if this is the same for everyone else.
# FR: Je ne peux que me demander si c'est la même chose pour tous les autres.
#
# EN: I suppose it's different when you think about it over the long term.
# FR: Je suppose que c'est différent quand tu y penses à long terme.
#
# EN: I suppose it's different when you think about it over the long term.
# FR: Je suppose que c'est différent quand vous y pensez à long terme.
#
# EN: I miss you.
# FR: Tu me manques.
#
# EN: I miss you.
# FR: Vous me manquez.
#
# EN: I'll call them tomorrow when I come back.
# FR: Je les appellerai demain quand je reviendrai.
#
# EN: I always liked mysterious characters more.
# FR: J'ai toujours plus apprécié les personnages mystérieux.
#
# EN: I always liked mysterious characters more.
# FR: J’ai toujours préféré les personnages mystérieux.
#
# EN: You should sleep.
# FR: Tu devrais dormir.
#
# EN: I'm going to go.
# FR: Je vais y aller.
#
# EN: I told them to send me another ticket.
# FR: Je leur ai dit de m'envoyer un autre ticket.
#
# EN: You're so impatient with me.
# FR: Tu es tellement impatiente avec moi.
#
# EN: You're so impatient with me.
# FR: Tu es tellement impatient avec moi.
#
# EN: I can't live that kind of life.
# FR: Je ne peux pas vivre comme ça.
#
# EN: I once wanted to be an astrophysicist.
# FR: Il fut un temps où je voulais être astrophysicien.
#
# EN: I never liked biology.
# FR: Je n'ai jamais aimé la biologie.
#
# EN: The last person I told my idea to thought I was nuts.
# FR: La dernière personne à qui j'ai raconté mon idée a pensé que j'étais cinglé.
#
# EN: If the world weren't in the shape it is now, I could trust anyone.
# FR: Si le monde n'était pas dans l'état où il est maintenant, je pourrais faire confiance à n'importe qui.
#
# EN: It is unfortunately true.
# FR: C'est malheureusement vrai.
#
# EN: They are too busy fighting against each other to care for common ideals.
# FR: Ils sont trop occupés à se battre entre eux pour s'occuper d'idéaux communs.
#
# EN: Most people think I'm crazy.
# FR: La plupart des gens pensent que je suis fou.
#
# EN: Most people think I'm crazy.
# FR: La plupart des gens pensent que je suis cinglé.
#
# EN: No I'm not; you are!
# FR: Non je ne le suis pas, c'est toi qui l'es !
#
# EN: No I'm not; you are!
# FR: Non, ce n'est pas moi, c'est toi !
#
# EN: That's MY line!
# FR: C'est ma réplique !
#
# EN: He's kicking me!
# FR: Il me donne des coups de pied !
#
# EN: Are you sure?
# FR: Est-ce que tu es sûr ?
#
# EN: Are you sure?
# FR: Es-tu sûr ?
#
# EN: Are you sure?
# FR: Es-tu sûre ?
#
# EN: Are you sure?
# FR: Êtes-vous sûr ?
#
# EN: Are you sure?
# FR: Êtes-vous sûre ?
#
# EN: Are you sure?
# FR: Êtes-vous sûres ?
#
# EN: Are you sure?
# FR: Êtes-vous sûrs ?
#
# EN: Are you sure?
# FR: Êtes-vous sûr ?
#
# EN: Are you sure?
# FR: Es-tu sûr ?
#
# EN: Are you sure?
# FR: Êtes-vous sûrs ?
#
# EN: Are you sure?
# FR: Êtes-vous sûres ?
#
# EN: Then there is a problem...
# FR: Alors il y a un problème...
#
# EN: Oh, there's a butterfly!
# FR: Oh, il y a un papillon !
#
# EN: Oh, there's a butterfly!
# FR: Oh, un papillon !
#
# EN: Oh, there's a butterfly!
# FR: Oh, il y a un papillon !
#
# EN: Hurry up.
# FR: Dépêche-toi !
#
# EN: Hurry up.
# FR: Dépêche-toi.
#
# EN: Hurry up.
# FR: Grouille !
#
# EN: Hurry up.
# FR: Vite!
#
# EN: Hurry up.
# FR: Pressez-vous !
#
# EN: Hurry up.
# FR: Fiça !
#
# EN: It doesn't surprise me.
# FR: Ça ne me surprend pas.
#
# EN: It doesn't surprise me.
# FR: Cela ne me surprend pas.
#
# EN: For some reason I feel more alive at night.
# FR: Pour une certaine raison je me sens plus vivant la nuit.
#
# EN: It depends on the context.
# FR: Ça dépend du contexte.
#
# EN: Are you freaking kidding me?!
# FR: Est-ce que tu te fous de moi ? !
#
# EN: Are you freaking kidding me?!
# FR: Est-ce que tu te fous de moi ?
#
# EN: That's the stupidest thing I've ever said.
# FR: C'est la chose la plus stupide que j'ai jamais dite.
#
# EN: I don't want to be lame; I want to be cool!!
# FR: Je ne veux pas être lamentable, je veux être cool ! !
#
# EN: I don't want to be lame; I want to be cool!!
# FR: Je ne veux pas être tendu, je veux être détendu !!
#
# EN: When I grow up, I want to be a king.
# FR: Quand je serai grand, je veux être roi.
#
# EN: When I grow up, I want to be a king.
# FR: Lorsque je serai grand, je veux être roi.
#
# EN: America is a lovely place to be, if you are here to earn money.
# FR: L'Amérique est un endroit charmant pour vivre, si c'est pour gagner de l'argent.
#
# EN: America is a lovely place to be, if you are here to earn money.
# FR: L'Amérique est un endroit merveilleux pour y vivre, si vous êtes là-bas pour gagner de l'argent.
#
# EN: I'm so fat.
# FR: Je suis si gros.
#
# EN: I'm so fat.
# FR: Je suis tellement gros.
#
# EN: So what?
# FR: Et alors ?
#
# EN: So what?
# FR: Eh bien, quoi ?
#
# EN: So what?
# FR: Et donc ?
#
# EN: So what?
# FR: Et alors ?
#
# EN: I'm gonna shoot him.
# FR: J'vais l'descendre.
#
# EN: I'm not a real fish, I'm just a mere plushy.
# FR: Je ne suis pas un vrai poisson, je ne suis qu'une simple peluche.
#
# EN: I'm just saying!
# FR: Je ne fais que parler !
#
# EN: That was probably what influenced their decision.
# FR: C'était probablement ce qui a influencé leur décision.
#
# EN: I've always wondered what it'd be like to have siblings.
# FR: Je me suis toujours demandé ce que ça ferait d'avoir des frères et sœurs.
#
# EN: This is what I would have said.
# FR: C'est ce que j'aurais dit.
#
# EN: It would take forever for me to explain everything.
# FR: Ça me prendrait l'éternité pour tout expliquer.
#
# EN: That's because you're a girl.
# FR: C'est parce que tu es une fille.
#
# EN: That's because you're a girl.
# FR: C'est parce que t'es une nana.
#
# EN: Sometimes I can't help showing emotions.
# FR: Parfois je ne peux pas m'empêcher de montrer des émotions.
#
# EN: It's a word I'd like to find a substitute for.
# FR: C'est un mot pour lequel j'aimerais trouver un substitut.
#
# EN: It would be something I'd have to program.
# FR: Ce serait quelque chose qu'il faudrait que je programme.
#
# EN: I don't intend to be selfish.
# FR: Il n'est pas dans mon intention d'être égoïste.
#
# EN: Let's consider the worst that could happen.
# FR: Réfléchissons au pire qui pourrait arriver.
#
# EN: How many close friends do you have?
# FR: Combien d'amis proches est-ce que tu as ?
#
# EN: How many close friends do you have?
# FR: Combien d'amis proches avez-vous ?
#
# EN: I may be antisocial, but it doesn't mean I don't talk to people.
# FR: Il se peut que je sois antisocial, mais ça ne veut pas dire pas que je ne parle pas aux gens.
#
# EN: This is always the way it has been.
# FR: C'est toujours tel que ça a été.
#
# EN: This is always the way it has been.
# FR: Il en a toujours été ainsi.
#
# EN: I think it is best not to be impolite.
# FR: Je pense que c'est mieux de ne pas être impoli.
#
# EN: One can always find time.
# FR: On peut toujours trouver du temps.
#
# EN: I'd be unhappy, but I wouldn't kill myself.
# FR: Je serais malheureux, mais je ne me suiciderais pas.
#
# EN: Back in high school, I got up at 6 a.m. every morning.
# FR: À l'époque du lycée je me levais à 6h tous les matins.
#
# EN: When I woke up, I was sad.
# FR: Quand je me suis réveillé j'étais triste.
#
# EN: That is somewhat explained at the end.
# FR: C’est ce qui est expliqué à la fin.
#
# EN: I thought you liked to learn new things.
# FR: Je pensais que tu aimais apprendre de nouvelles choses.
#
# EN: I thought you liked to learn new things.
# FR: Je croyais que tu aimais apprendre de nouvelles choses.
#
# EN: Most people write about their daily life.
# FR: La plupart des gens écrivent à propos de leur vie quotidienne.
#
# EN: If I could send you a marshmallow, Trang, I would.
# FR: Si je pouvais t'envoyer un marshmallow, Trang, je le ferais.
#
# EN: If I could send you a marshmallow, Trang, I would.
# FR: Si je pouvais t'envoyer une guimauve, Trang, je le ferais.
#
# EN: In order to do that, you have to take risks.
# FR: Pour faire cela, il te faut prendre des risques.
#
# EN: Every person who is alone is alone because they are afraid of others.
# FR: Chaque personne qui est seule est seule parce qu'elle a peur des autres.
#
# EN: Every person who is alone is alone because they are afraid of others.
# FR: Toutes les personnes qui sont seules le sont car elles ont peur des autres.
#
# EN: Why do you ask?
# FR: Pourquoi demandes-tu ?
#
# EN: I am not an artist. I never had the knack for it.
# FR: Je ne suis pas un artiste. Je n'ai jamais eu l'esprit pour ça.
#
# EN: I am a flawed person, but these are flaws that can easily be fixed.
# FR: Je suis une personne qui a des défauts, mais ces défauts peuvent être facilement corrigés.
#
# EN: Whenever I find something I like, it's too expensive.
# FR: Chaque fois que je trouve quelque chose que j'aime, c'est trop cher.
#
# EN: How long did you stay?
# FR: Combien de temps es-tu restée ?
#
# EN: How long did you stay?
# FR: Combien de temps y avez-vous séjourné ?
#
# EN: How long did you stay?
# FR: Combien de temps es-tu resté ?
#
# EN: How long did you stay?
# FR: Combien de temps êtes-vous restée ?
#
# EN: How long did you stay?
# FR: Combien de temps êtes-vous resté ?
#
# EN: How long did you stay?
# FR: Combien de temps êtes-vous restées ?
#
# EN: How long did you stay?
# FR: Combien de temps êtes-vous restés ?
#
# EN: How long did you stay?
# FR: Combien de temps y as-tu séjourné ?
#
# EN: Maybe it will be exactly the same for him.
# FR: Peut-être que ce sera la même chose pour lui.
#
# EN: Innocence is a beautiful thing.
# FR: L'innocence est une belle chose.
#
# EN: Humans were never meant to live forever.
# FR: Les humains n'ont jamais été faits pour vivre éternellement.
#
# EN: I don't want to lose my ideas, even though some of them are a bit extreme.
# FR: Je ne veux pas perdre mes idées, même si certaines d'entre elles sont un peu extrêmes.
#
# EN: I think I have a theory about that.
# FR: Je pense que j'ai une théorie à ce sujet.
#
# EN: That is intriguing.
# FR: C'est intrigant.
#
# EN: You are saying you intentionally hide your good looks?
# FR: Tu es en train de dire que tu caches intentionnellement ta beauté ?
#
# EN: I do not have an account in these forums.
# FR: Je n’ai pas de compte sur ces forums.
#
# EN: If anyone was to ask what the point of the story is, I really don't know.
# FR: Si quelqu'un devait demander quel est le but de l'histoire, je ne saurais vraiment pas.
#
# EN: I didn't know where it came from.
# FR: Je ne savais pas d'où ça venait.
#
# EN: I think my living with you has influenced your way of living.
# FR: Je pense que le fait que j'ai vécu avec toi a influencé la façon dont tu vis.
#
# EN: This is not important.
# FR: Ce n'est pas important.
#
# EN: I didn't like it.
# FR: Je n'ai pas aimé.
#
# EN: I didn't like it.
# FR: Ça ne me plaisait pas.
#
# EN: She's asking how that's possible.
# FR: Elle demande comment c’est possible.
#
# EN: You're just running away from life's problems.
# FR: Tu ne fais que fuir les problèmes de la vie.
#
# EN: If you look at the lyrics, they don't really mean much.
# FR: Si tu regardes les paroles, elles ne signifient pas vraiment grand-chose.
#
# EN: There's a problem there that you don't see.
# FR: Il y a un problème que tu ne vois pas.
#
# EN: You can do it.
# FR: Tu peux le faire !
#
# EN: You can do it.
# FR: Tu peux y arriver.
#
# EN: You can do it.
# FR: C'est bon, tu peux le faire.
#
# EN: You can do it.
# FR: Tu peux le faire.
#
# EN: You can do it.
# FR: Vous pouvez y arriver.
#
# EN: You can do it.
# FR: Vous pouvez le faire.
#
# EN: My physics teacher doesn't care if I skip classes.
# FR: Mon prof de physique s'en fiche si je sèche les cours.
#
# EN: I wish I could go to Japan.
# FR: J'aimerais bien pouvoir aller au Japon.
#
# EN: I hate it when there are a lot of people.
# FR: Je déteste ça quand il y a trop de gens.
#
# EN: I have to go to bed.
# FR: Je dois aller au lit.
#
# EN: I have to go to bed.
# FR: Je dois aller dormir.
#
# EN: After that, I left, but then I realized that I forgot my backpack at their house.
# FR: Après ça, je pars, mais je me rends compte que j'ai oublié mon sac chez eux.

# %%
# Encode English queries
english_embeddings = model.encode(english_sentences, convert_to_tensor=True)

# Encode French documents
french_embeddings = model.encode(french_sentences, convert_to_tensor=True)

# %% [markdown]
# ## 🔍 Step 4: Semantic Matching with Cosine Similarity
#
# In this step, we’ll:
# - Use cosine similarity to compare English sentence embeddings with all French sentence embeddings
# - Retrieve the most similar French sentence for each English query
# - This mimics how a cross-lingual search engine would work
#
# Cosine similarity gives a score between -1 and 1:
# - 1 = perfect match
# - 0 = no similarity
# - -1 = completely opposite

# %%
from sentence_transformers.util import cos_sim
import torch

top_matches = []
correct_predictions = 0
total_queries = len(english_embeddings)

# Loop over each English query
for idx, query_embedding in enumerate(english_embeddings):
    # Compute similarity with all French documents
    cosine_scores = cos_sim(query_embedding, french_embeddings)[0]
    
    # Find the top match
    top_match_idx = torch.argmax(cosine_scores).item()
    
    # Check if match is correct (same index)
    is_correct = (top_match_idx == idx)
    if is_correct:
        correct_predictions += 1

    # Store the result
    top_matches.append({
        "english_query": english_sentences[idx],
        "matched_french_doc": french_sentences[top_match_idx],
        "similarity_score": float(cosine_scores[top_match_idx]),
        "correct": is_correct
    })

# Accuracy summary
accuracy = correct_predictions / total_queries * 100
print(f"\n✅ Top-1 Accuracy: {accuracy:.2f}% ({correct_predictions}/{total_queries})\n")

# Show sample matches
for match in top_matches[:5]:  # show only first 5 for readability
    print(f"English Query: {match['english_query']}")
    print(f"Matched French Doc: {match['matched_french_doc']}")
    print(f"Similarity Score: {match['similarity_score']:.4f}")
    print(f"Correct Match: {'Yes' if match['correct'] else 'No'}\n")
# Out:
# ✅ Top-1 Accuracy: 56.50% (113/200)
#
# English Query: When he asked who had broken the window, all the boys put on an air of innocence.
# Matched French Doc: Lorsqu'il a demandé qui avait cassé la fenêtre, tous les garçons ont pris un air innocent.
# Similarity Score: 0.9428
# Correct Match: Yes
#
# English Query: Then, when he asked who had broken the window, all the boys acted innocent.
# Matched French Doc: Lorsqu'il a demandé qui avait cassé la fenêtre, tous les garçons ont pris un air innocent.
# Similarity Score: 0.9525
# Correct Match: No
#
# English Query: Let's try something.
# Matched French Doc: Essayons quelque chose.
# Similarity Score: 0.9937
# Correct Match: No
#
# English Query: Let's try something.
# Matched French Doc: Essayons quelque chose.
# Similarity Score: 0.9937
# Correct Match: No
#
# English Query: Let's try something.
# Matched French Doc: Essayons quelque chose.
# Similarity Score: 0.9937
# Correct Match: Yes

# %% [markdown]
# ## 📁 Step 5: Save Results to CSV
#
# We'll now save all results to a `.csv` file, including:
# - English queries
# - Matched French documents
# - Cosine similarity scores
# - Whether the top match was correct
#
# This makes it easy to:
# - Analyze results in Excel or Python
# - Share your model output on GitHub or with recruiters

# %%
import pandas as pd

# Convert list of match results into a DataFrame
results_df = pd.DataFrame(top_matches)

# Save to CSV
results_df.to_csv("cross_lingual_results.csv", index=False)

print("Results saved to cross_lingual_results.csv")
results_df.head()
# Out:
# Results saved to cross_lingual_results.csv
#                                        english_query  \
# 0  When he asked who had broken the window, all t...
# 1  Then, when he asked who had broken the window,...
# 2                               Let's try something.
# 3                               Let's try something.
# 4                               Let's try something.
#
#                                   matched_french_doc  similarity_score  \
# 0  Lorsqu'il a demandé qui avait cassé la fenêtre...          0.942797
# 1  Lorsqu'il a demandé qui avait cassé la fenêtre...          0.952528
# 2                            Essayons quelque chose.          0.993729
# 3                            Essayons quelque chose.          0.993729
# 4                            Essayons quelque chose.          0.993729
#
#    correct
# 0     True
# 1    False
# 2    False
# 3    False
# 4     True

# %% [markdown]
# ## 💬 Step 6: Interactive User Input for Query Matching
#
# We'll now build a simple interactive demo in Jupyter where you can:
#
# - Enter a custom **English query**
# - See the **top 3 most similar French documents**
# - View their **similarity scores**
#
# This simulates how a real-world cross-lingual search system could work.

# %%
def search_french_docs(user_query, top_k=3):
    # Encode the user query
    query_embedding = model.encode(user_query, convert_to_tensor=True)
    
    # Compute similarity with all French embeddings
    cosine_scores = cos_sim(query_embedding, french_embeddings)[0]
    
    # Get top k match indices
    top_results = torch.topk(cosine_scores, k=top_k)

    print(f"\nYour Query: {user_query}\n")
    print("Top Matches:\n")

    for score, idx in zip(top_results[0], top_results[1]):
        print(f"French Doc: {french_sentences[idx]}")
        print(f"Similarity Score: {score.item():.4f}\n")

# 🔁 Run this as many times as you want
user_input = input("Enter your English query: ")
search_french_docs(user_input)
# Out:
# Enter your English query:  America is a lovely place to be, if you are here to earn money.
# Your Query: America is a lovely place to be, if you are here to earn money.
#
# Top Matches:
#
# French Doc: L'Amérique est un endroit charmant pour vivre, si c'est pour gagner de l'argent.
# Similarity Score: 0.9424
#
# French Doc: L'Amérique est un endroit merveilleux pour y vivre, si vous êtes là-bas pour gagner de l'argent.
# Similarity Score: 0.9423
#
# French Doc: C'est bon, tu peux le faire.
# Similarity Score: 0.3179

# %% [markdown]
# ## 💾 Step 7: Save Embeddings and Sentences to File for Flask deployment
#
# To make our Flask app fast and efficient, we’ll pre-compute the following and save them in a `.pkl` (pickle) file:
#
# - English sentences (as queries)
# - French sentences (as retrievable documents)
# - French sentence embeddings (vector form for similarity search)
#
# This avoids re-running the model every time a user enters a query and makes deployment smoother.
#
# We’ll later load this file inside `utils.py` in our Flask app.

# %%
# ✅ Step 1: Save model embeddings and sentences to a .pkl file

import pickle

# Save English and French sentence lists and French embeddings
with open("AI-CrossLingual-Flask-App/embeddings.pkl", "wb") as f:
    pickle.dump({
        "english_sentences": english_sentences,
        "french_sentences": french_sentences,
        "french_embeddings": french_embeddings
    }, f)

print("Embeddings and sentences saved to embeddings.pkl!")
# Out:
# Embeddings and sentences saved to embeddings.pkl!

# %% [markdown]
# ## 🛠️ Step 8: Create `utils.py` inside AI-CrossLingual-Flask-App/utils.py
#
# This file will:
# - Load the multilingual model
# - Load the saved embeddings (English, French, vectorized)
# - Define a function to perform cosine similarity search

# %% [markdown]
# ## 🌐 Step 9: Create `app.py`
#
# This is the main Flask backend file. It will:
# - Serve the HTML UI
# - Accept English query from user
# - Return top-matching French documents using `utils.py`

# %% [markdown]
# ## 🖼️ Step 10: Create `templates/index.html`
#
# This is the frontend UI of our Flask app. It lets the user:
# - Enter an English query
# - View top-matching French sentences + similarity scores
# - commands to run this - cd AI-CrossLingual-Flask-App, flask run
# - Then open: http://127.0.0.1:5000 in your browser
